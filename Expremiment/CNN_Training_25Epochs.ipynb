# %%
import tensorflow as tf
import os
import numpy as np
from matplotlib import pyplot as plt
import cv2
import imghdr
import pandas as pd

# %% [markdown]
# Load Data

# %%
data_dir = 'Affectnet Dataset'
data=pd.read_csv('Affectnet Dataset\labels.csv')
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\l'
# <>:2: SyntaxWarning: invalid escape sequence '\l'
# C:\Users\biswa\AppData\Local\Temp\ipykernel_7896\3271766593.py:2: SyntaxWarning: invalid escape sequence '\l'
#   data=pd.read_csv('Affectnet Dataset\labels.csv')

# %%
data.head()
# Out:
#    Unnamed: 0                     pth     label    relFCs
# 0           0  anger/image0000006.jpg  surprise  0.873142
# 1           1  anger/image0000060.jpg     anger  0.852311
# 2           2  anger/image0000061.jpg     anger  0.800957
# 3           3  anger/image0000066.jpg   disgust  0.843079
# 4           4  anger/image0000106.jpg     anger  0.849108

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28175 entries, 0 to 28174
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  28175 non-null  int64
#  1   pth         28175 non-null  object
#  2   label       28175 non-null  object
#  3   relFCs      28175 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 880.6+ KB

# %%
X = data['pth'].values
y = data['label'].values

# %%
X
# Out:
# array(['anger/image0000006.jpg', 'anger/image0000060.jpg',
#        'anger/image0000061.jpg', ..., 'surprise/image0034966.jpg',
#        'surprise/image0034973.jpg', 'surprise/image0042075.jpg'],
#       dtype=object)

# %%
'''img = cv2.imread(data_dir+"/"+X[4]) 
#img = cv2.imread(data_dir+"/"+image_path) 
clf = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
    #faces contains coordinates of the face
faces = clf.detectMultiScale(img, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))
print(f'Faces : {faces}\n')
    
input_image = cv2.cvtColor(img[faces[0][1]:(faces[0][1]+faces[0][3]),faces[0][0]:(faces[0][0]+faces[0][3])],cv2.COLOR_BGR2RGB)   '''
    
#input_image = cv2.cvtColor(img[faces[0][1]:(faces[0][1]+faces[0][3]),faces[0][0]:(faces[0][0]+faces[0][3])],cv2.COLOR_BGR2RGB)
# Out:
# 'img = cv2.imread(data_dir+"/"+X[4]) \n#img = cv2.imread(data_dir+"/"+image_path) \nclf = cv2.CascadeClassifier(cv2.data.haarcascades + \'haarcascade_frontalface_default.xml\')\n    #faces contains coordinates of the face\nfaces = clf.detectMultiScale(img, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))\nprint(f\'Faces : {faces}\n\')\n    \ninput_image = cv2.cvtColor(img[faces[0][1]:(faces[0][1]+faces[0][3]),faces[0][0]:(faces[0][0]+faces[0][3])],cv2.COLOR_BGR2RGB)   '

# %%
print(X.size)
print()
# Out:
# 28175

# %%
from sklearn.preprocessing import LabelEncoder
from keras.utils import to_categorical
import cv2

def preprocess_image(image_path):
    #skip=0
    img = cv2.imread(data_dir+"/"+image_path) 
    clf = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
    #faces contains coordinates of the face
    faces = clf.detectMultiScale(img, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))
    #print(f'Faces : {faces}\n')
    if(len(faces)==0):
        return cv2.cvtColor(img,cv2.COLOR_BGR2RGB)/255.0
    else:
        input_image = cv2.cvtColor(img[faces[0][1]:(faces[0][1]+faces[0][3]),faces[0][0]:(faces[0][0]+faces[0][3])],cv2.COLOR_BGR2RGB)   
        img_normalized = input_image / 255.0
        return img_normalized

# %%
X_preprocessed=[]
count=0
skip=0
for image_path in X:
    count+=1
    print(count)
    print(image_path)
    X_preprocessed.append(preprocess_image(image_path))
    # temp = preprocess_image(image_path)
    # if(temp!=-1):
    #     X_preprocessed.append(temp)
    # else:
    #     skip+=1
    #     X_preprocessed.append()
#X_preprocessed=np.array([preprocess_image(image_path) for image_path in X])
#X_preprocessed=np.array(X_preprocessed)

le = LabelEncoder()
y_preprocessed = to_categorical(le.fit_transform(y))
# Out:
# 1
# anger/image0000006.jpg
# 2
# anger/image0000060.jpg
# 3
# anger/image0000061.jpg
# 4
# anger/image0000066.jpg
# 5
# anger/image0000106.jpg
# 6
# anger/image0000132.jpg
# 7
# anger/image0000138.jpg
# 8
# anger/image0000182.jpg
# 9
# anger/image0000195.jpg
# 10
# anger/image0000213.jpg
# 11
# anger/image0000228.jpg
# 12
# anger/image0000294.jpg
# 13
# anger/image0000333.jpg
# 14
# anger/image0000343.jpg
# 15
# anger/image0000346.jpg
# 16
# anger/image0000356.jpg
# 17
# anger/image0000368.jpg
# 18
# anger/image0000374.jpg
# 19
# anger/image0000390.jpg
# 20
# anger/image0000399.jpg
# 21
# anger/image0000407.jpg
# 22
# anger/image0000415.jpg
# 23
# anger/image0000416.jpg
# 24
# anger/image0000441.jpg
# 25
# anger/image0000450.jpg
# 26
# anger/image0000470.jpg
# 27
# anger/image0000511.jpg
# 28
# anger/image0000513.jpg
# 29
# anger/image0000593.jpg
# 30
# anger/image0000602.jpg
# 31
# anger/image0000690.jpg
# 32
# anger/image0000697.jpg
# 33
# anger/image0000722.jpg
# 34
# anger/image0000723.jpg
# 35
# anger/image0000758.jpg
# 36
# anger/image0000776.jpg
# 37
# anger/image0000908.jpg
# 38
# anger/image0000923.jpg
# 39
# anger/image0000932.jpg
# 40
# anger/image0000949.jpg
# 41
# anger/image0000963.jpg
# 42
# anger/image0000965.jpg
# 43
# anger/image0000972.jpg
# 44
# anger/image0000996.jpg
# 45
# anger/image0001015.jpg
# 46
# anger/image0001021.jpg
# 47
# anger/image0001061.jpg
# 48
# anger/image0001062.jpg
# 49
# anger/image0001063.jpg
# 50
# anger/image0001066.jpg
# 51
# anger/image0001086.jpg
# 52
# anger/image0001113.jpg
# 53
# anger/image0001120.jpg
# 54
# anger/image0001152.jpg
# 55
# anger/image0001161.jpg
# 56
# anger/image0001241.jpg
# 57
# anger/image0001244.jpg
# 58
# anger/image0001258.jpg
# 59
# anger/image0001283.jpg
# 60
# anger/image0001296.jpg
# 61
# anger/image0001305.jpg
# 62
# anger/image0001314.jpg
# surprise/image0034864.jpg
# 28146
# surprise/image0034868.jpg
# 28147
# surprise/image0034874.jpg
# 28148
# surprise/image0034879.jpg
# 28149
# surprise/image0034882.jpg
# 28150
# surprise/image0034886.jpg
# 28151
# surprise/image0034887.jpg
# 28152
# surprise/image0034891.jpg
# 28153
# surprise/image0034892.jpg
# 28154
# surprise/image0034893.jpg
# 28155
# surprise/image0034896.jpg
# 28156
# surprise/image0034900.jpg
# 28157
# surprise/image0034901.jpg
# 28158
# surprise/image0034902.jpg
# 28159
# surprise/image0034903.jpg
# 28160
# surprise/image0034906.jpg
# 28161
# surprise/image0034908.jpg
# 28162
# surprise/image0034915.jpg
# 28163
# surprise/image0034920.jpg
# 28164
# surprise/image0034929.jpg
# 28165
# surprise/image0034931.jpg
# 28166
# surprise/image0034939.jpg
# 28167
# surprise/image0034946.jpg
# 28168
# surprise/image0034947.jpg
# 28169
# surprise/image0034951.jpg
# 28170
# surprise/image0034957.jpg
# 28171
# surprise/image0034960.jpg
# 28172
# surprise/image0034961.jpg
# 28173
# surprise/image0034966.jpg
# 28174
# surprise/image0034973.jpg
# 28175
# surprise/image0042075.jpg
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 16
#       8     X_preprocessed.append(preprocess_image(image_path))
#       9     # temp = preprocess_image(image_path)
#      10     # if(temp!=-1):
#      11     #     X_preprocessed.append(temp)
#    (...)
#      14     #     X_preprocessed.append()
#      15 #X_preprocessed=np.array([preprocess_image(image_path) for image_path in X])
# ---> 16 X_preprocessed=np.array(X_preprocessed)
#      18 le = LabelEncoder()
#      19 y_preprocessed = to_categorical(le.fit_transform(y))
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (28175,) + inhomogeneous part.

# %%
le = LabelEncoder()
y_preprocessed = to_categorical(le.fit_transform(y))

# %%
type(X_preprocessed)
# Out:
# list

# %%
len(X_preprocessed)
# Out:
# 28175

# %%
print(len(X_preprocessed))
print(len(y_preprocessed))
# Out:
# 28175
# 28175

# %%
#X_preprocessed=np.array([preprocess_image(image_path) for image_path in X])
# data_dir='Affectnet Dataset'
# X_preprocessed=[]

# for image_path in X:
#     img = cv2.imread(data_dir+"/"+image_path)    
#     img_normalized = img/255.0
#     X_preprocessed.append(img_normalized)
#     # 


# X_preprocessed=np.array(X_preprocessed)

# %% [markdown]
# Spliting Test train

# %%
from sklearn.model_selection import train_test_split

# Split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_preprocessed, y_preprocessed, test_size=0.2, random_state=42, stratify=y)

# %% [markdown]
# Creating CNN model

# %% [markdown]
# Building Deep learning model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout

# %%
model = Sequential()

model.add(Conv2D(64, (3,3), 1, activation='relu', input_shape=(96,96,3)))#Convolution layer 1
model.add(Conv2D(128, (3,3), 1, activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))#Pooling layer 1
model.add(Dropout(0.25))

model.add(Conv2D(256, (3,3), 1, activation='relu'))#Convolution layer 2
model.add(MaxPooling2D(pool_size=(2,2)))#Pooling layer 2
model.add(Conv2D(16, (3,3), 1, activation='relu'))#Convolution layer 3
model.add(MaxPooling2D(pool_size=(2,2)))#Pooling layer 3
model.add(Dropout(0.25))

model.add(Flatten())#Fully Connected layer
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.5))


#model.add(Dense(256, activation='relu'))
model.add(Dense(8, activation='softmax'))#Output layer
# Out:
# c:\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(

# %%
from keras import metrics

# model.compile(loss='mean_squared_error', optimizer='sgd',
#               metrics=[metrics.mae,
#                        metrics.categorical_accuracy])

model.compile(optimizer='adam', 
          loss='categorical_crossentropy', 
          metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 94, 94, 64)     │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 92, 92, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 46, 46, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 46, 46, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 44, 44, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 22, 22, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 20, 20, 16)     │        36,880 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 10, 10, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 10, 10, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1600)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1024)           │     1,639,424 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 8)              │         8,200 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,055,320 (7.84 MB)
#  Trainable params: 2,055,320 (7.84 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
#model.compile('sgd', loss=tf.losses.CategoricalCrossentropy(), metrics=['accuracy'])

# %% [markdown]
# Visualize CNN model

# %%
import visualkeras
visualkeras.layered_view(model).show() # display using your system viewer
visualkeras.layered_view(model, to_file='Neural_Network_Visualize.png') # write to disk
visualkeras.layered_view(model, to_file='Neural_Network_Visualize.png').show() # write and show

# %% [markdown]
# Train

# %%
logdir='logs'

# %%
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)

# %%
Log_history = model.fit(X_train,y_train, epochs=25, batch_size=64,validation_split=0.2,callbacks=[tensorboard_callback])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 Log_history = model.fit(X_train,y_train, epochs=25, batch_size=64,validation_split=0.2,callbacks=[tensorboard_callback])
#
# File c:\Python312\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File c:\Python312\Lib\site-packages\keras\src\trainers\data_adapters\data_adapter_utils.py:114, in check_data_cardinality(data)
#     110     sizes = ", ".join(
#     111         str(i.shape[0]) for i in tree.flatten(single_data)
#     112     )
#     113     msg += f"'{label}' sizes: {sizes}\n"
# --> 114 raise ValueError(msg)
#
# ValueError: Data cardinality is ambiguous. Make sure all arrays contain the same number of samples.'x' sizes: 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48 ...
# 'y' sizes: 48

# %%
model.save_weights('models/Scaled_model.h5')

# %%
import pandas as pd
pd.DataFrame(Log_history.history).plot()

# %% [markdown]
# Performance

# %%
label_mapping={0: 'anger',
 1: 'contempt',
 2: 'disgust',
 3: 'fear',
 4: 'happy',
 5: 'neutral',
 6: 'sad',
 7: 'surprise'}

# %%
from sklearn.metrics import roc_curve, auc, precision_score, recall_score, f1_score

y_pred_prob=model.predict(X_test)
# Convert probabilities to binary predictions
y_pred_labels = np.argmax(y_pred_prob, axis=1)

# Convert y_test to binary labels
y_true_labels = np.argmax(y_test, axis=1)

# List to store individual precision, recall, and F1-score values for each class
class_metrics = []

# List to store individual AUC values and ROC curves for each class
roc_curves = []


for i in range(8):
    # Convert predicted and true labels to binary labels
    y_pred_binary = (y_pred_labels == i)
    y_true_binary = (y_true_labels == i)
    
    # Calculate precision, recall, and F1-score
    precision = precision_score(y_true_binary, y_pred_binary)
    recall = recall_score(y_true_binary, y_pred_binary)
    f1 = f1_score(y_true_binary, y_pred_binary)
    
    # ROC curve calculation
    fpr, tpr, _ = roc_curve(y_true_binary, y_pred_prob[:, i])
    roc_auc = auc(fpr, tpr)
    roc_curves.append((fpr, tpr, label_mapping[i]))
    
    # Store metrics in a dictionary
    class_metrics.append({
        'Label': label_mapping[i],
        'Precision': precision,
        'Recall': recall,
        'F1-score': f1,
        'AUC': roc_auc
    })


    
# Compute and plot macro-average ROC curve
mean_fpr = np.linspace(0, 1, 100)
mean_tpr = np.mean([np.interp(mean_fpr, fpr, tpr) for fpr, tpr, _ in roc_curves], axis=0)
macro_auc = auc(mean_fpr, mean_tpr)




# Calculate overall precision, recall, and F1-score
overall_precision = precision_score(y_true_labels, y_pred_labels, average='macro')
overall_recall = recall_score(y_true_labels, y_pred_labels, average='macro')
overall_f1 = f1_score(y_true_labels, y_pred_labels, average='macro')

class_metrics.append({
    'Label': 'Overall',
    'Precision': overall_precision,
    'Recall': overall_recall,
    'F1-score': overall_f1,
    'AUC': macro_auc
})


# Create a Pandas DataFrame from the list of metrics
metrics_df = pd.DataFrame(class_metrics)

# Optionally, print the metrics table
print(metrics_df)


# Plot ROC curve for each class
plt.figure(figsize=(12, 8))
lw = 2

    
for fpr, tpr, label in roc_curves:
    plt.plot(fpr, tpr, lw=lw, label='ROC curve (area = {:.2f}) for Emotion: {}'.format(roc_auc, label))

plt.plot(mean_fpr, mean_tpr, color='darkorange', linestyle='--', linewidth=2, label='Macro-average ROC curve (area = {:.2f})'.format(macro_auc))


plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic for Each Class')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# Evaluate performance

# %% [markdown]
# Test

# %%
img = cv2.imread('test/happy.jpg')
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
plt.show()

# %%
img.shape

# %%
resize = tf.image.resize(img, (96,96))
plt.imshow(resize.numpy().astype(int))
plt.show()

# %%
import numpy as np

# %%
resize.shape

# %%
np.expand_dims(resize,0).shape

# %%
yhat = model.predict(np.expand_dims(resize/255, 0))

# %%
yhat

# %%
yhat

# %%
classify_result = np.argmax(yhat)
classify_result

# %%
label_mapping={0: 'anger',
 1: 'contempt',
 2: 'disgust',
 3: 'fear',
 4: 'happy',
 5: 'neutral',
 6: 'sad',
 7: 'surprise'}

# %% [markdown]
# Save the model

# %%
from tensorflow.keras.models import load_model

# %%
model.save(os.path.join('models','Final_CNN_with25epochs.h5'))

# %%
new_model = load_model(os.path.join('models','Final_CNN_with25epochs.h5'))

# %%
new_model.predict(np.expand_dims(resize/255,0))

# %%
plt.imshow(resize)
